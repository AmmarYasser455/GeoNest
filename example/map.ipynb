# %%
from geonest import Map

# %%
m = Map(center=[30.0, 31.0], zoom=8)
m.add_basemap_gui()
m.add_layer_control()
m
# Out:
# Map(center=[30.0, 31.0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out…
